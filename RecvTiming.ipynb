# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime
# %matplotlib notebook

# %%
world_rank = 2
data = np.genfromtxt("build/out/recv_times_{}.csv".format(world_rank), delimiter=",", skip_header=1)

# %%
n = data[:, 0]
dt = 1000*data[:, 1]

# %%
plt.figure()
plt.loglog(n, dt, '+')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
n_val, n_count = np.unique(n, return_counts=True)


plt.figure()
plt.plot(n_val, n_count, '+-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.figure()
plt.hist(data[1:, 1]*1000, 200)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
np.amax(dt)
# Out:
# 10718.67299079895

# %%
plt.figure()
plt.plot(data[:,1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
(np.amax(n)*24*8)/np.amax(data[:, 1])/1e6
# Out:
# 8.874883680252047
